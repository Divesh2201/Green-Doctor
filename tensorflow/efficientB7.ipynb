# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import PIL
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import MultiLabelBinarizer
from tensorflow.keras.layers import MaxPooling2D,GlobalAveragePooling2D,BatchNormalization,Activation
import tensorflow_addons as tfa

# %%
from kaggle_secrets import UserSecretsClient
import wandb
from wandb.keras import WandbCallback
user_secrets = UserSecretsClient()
wandb_api = user_secrets.get_secret("wandb-api-key") 
wandb.login(key=wandb_api)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
train_directory = '../input/plant-pathology-2021-fgvc8/train_images'
test_directory =  '../input/plant-pathology-2021-fgvc8/test_images'

# %%
train_data = pd.read_csv('../input/plant-pathology-2021-fgvc8/train.csv')

# %%
train_data.head()
# Out:
#                   image                           labels
# 0  800113bb65efe69e.jpg                          healthy
# 1  8002cb321f8bfcdf.jpg  scab frog_eye_leaf_spot complex
# 2  80070f7fb5e2ccaa.jpg                             scab
# 3  80077517781fb94f.jpg                             scab
# 4  800cbf0ff87721f8.jpg                          complex

# %%
train_data['labels'].value_counts()
# Out:
# scab                               4826
# healthy                            4624
# frog_eye_leaf_spot                 3181
# rust                               1860
# complex                            1602
# powdery_mildew                     1184
# scab frog_eye_leaf_spot             686
# scab frog_eye_leaf_spot complex     200
# frog_eye_leaf_spot complex          165
# rust frog_eye_leaf_spot             120
# rust complex                         97
# powdery_mildew complex               87
# Name: labels, dtype: int64

# %%
plt.figure(figsize=(10,6))

labels = sns.barplot(train_data.labels.value_counts().index,train_data.labels.value_counts())

for item in labels.get_xticklabels():
    item.set_rotation(45)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train_data['labels'] = train_data['labels'].apply(lambda s: s.split(' '))

# %%
list_of_labels = list(train_data['labels'])

mlb = MultiLabelBinarizer()

label_dataframe = pd.DataFrame(mlb.fit_transform(list_of_labels), columns=mlb.classes_, index=train_data.index)

print(label_dataframe.columns)
# Out:
# Index(['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust',
#        'scab'],
#       dtype='object')

# %%
labels = list(label_dataframe.sum().keys())

label_counts = label_dataframe.sum().values.tolist()

fig, ax = plt.subplots(1,1, figsize=(10,6))

sns.barplot(x= labels, y= label_counts, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig1 = plt.figure(figsize=(12,12))

for i in range(1, 10):
    random_number =  random.randrange(1, 18000)
    sample_image = os.path.join('../input/plant-pathology-2021-fgvc8/train_images/', train_data['image'][random_number])
    
    img = PIL.Image.open(sample_image)
    
    ax = fig1.add_subplot(3,3,i)
    ax.imshow(img)
    
    title = f"{train_data['labels'][random_number]}   {img.size}"
    plt.title(title)
    
    fig1.tight_layout()

# %%
datagen = ImageDataGenerator(
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    brightness_range = None,
    shear_range = 0.1,
    zoom_range = 0.1,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split= 0.15
)

# %%
X_COL = 'image'
Y_COL = 'labels'
COLOR_MODE = 'rgb'
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
TARGET_SIZE = (IMAGE_HEIGHT,IMAGE_WIDTH)
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, 3)
CLASS_MODE = 'categorical'
BSIZE = 16

# %%
training_set = datagen.flow_from_dataframe(
    train_data,
    directory = '../input/resized-plant2021/img_sz_512',# We are using the resized images otherwise it will take a lot of time to train 
    x_col = X_COL,
    y_col = Y_COL,
    subset = "training",
    color_mode = COLOR_MODE,
    target_size = TARGET_SIZE,
    class_mode = CLASS_MODE,
    batch_size = BSIZE,
    shuffle=False,
    seed=40
)
# Out:
# Found 15838 validated image filenames belonging to 6 classes.

# %%
validation_set = datagen.flow_from_dataframe(
    train_data,
    directory = '../input/resized-plant2021/img_sz_512',
    x_col = X_COL,
    y_col = Y_COL,
    subset="validation",
    color_mode = COLOR_MODE,
    target_size = TARGET_SIZE,
    class_mode = CLASS_MODE,
    batch_size = BSIZE,
    shuffle=False,
    seed=40
)
# Out:
# Found 2794 validated image filenames belonging to 6 classes.

# %%
base_model = tf.keras.applications.EfficientNetB7(input_shape=INPUT_SHAPE, include_top=False,weights= "imagenet")

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
#fully connected layer
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dense(16, activation='relu')(x)

# finally, the softmax for the classifier 
predictions = tf.keras.layers.Dense(6, activation='sigmoid')(x)

# %%
model = tf.keras.Model(inputs=base_model.input ,outputs = predictions)

threshold_x = 0.25

optimizer = tf.keras.optimizers.Adam()

f1 = tfa.metrics.F1Score(num_classes=6, average='macro',threshold = threshold_x)

# %%
checkpoint_path = "training/efficientnet-cp-{epoch:04d}.ckpt"

# %%
#callback functions

learningrate_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                          factor=0.05, 
                                                          patience=5, 
                                                          verbose=1)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor=f1, 
                                                 patience=3, 
                                                 mode='max', 
                                                 restore_best_weights=True)


checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                        verbose=1, 
                                                        save_weights_only=True,
                                                        save_freq='epoch')

# %%
CONFIG = dict (
    num_labels = 6,
    train_val_split = 0.15,
    img_width = IMAGE_WIDTH,
    img_height = IMAGE_HEIGHT,
    batch_size = BSIZE,
    epochs = 15,
    learning_rate = 0.001,
    architecture = "CNN",
    infra = "Kaggle",
    model_name = "EfficientNet"
)

CONFIG['model_name'] = 'EfficientNet'

print('Training configuration: ', CONFIG)

# Initialize W&B run
run = wandb.init(project='plant-pathology', 
                 config=CONFIG,
                 group='EfficientNet', 
                 job_type='train')


callbacks_list = [early_stopping, learningrate_scheduler, checkpoint_callback, WandbCallback()]
# Out:
# Training configuration:  {'num_labels': 6, 'train_val_split': 0.15, 'img_width': 224, 'img_height': 224, 'batch_size': 16, 'epochs': 15, 'learning_rate': 0.001, 'architecture': 'CNN', 'infra': 'Kaggle', 'model_name': 'EfficientNet'}
# Finishing last run (ID:dfnpghs0) before initializing another...
# <br/>Waiting for W&B process to finish, PID 156<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/kaggle/working/wandb/run-20210827_123629-dfnpghs0/logs/debug.log</code>
# Find internal logs for this run at: <code>/kaggle/working/wandb/run-20210827_123629-dfnpghs0/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">confused-shape-2</strong>: <a href="https://wandb.ai/kushv16/plant-pathology/runs/dfnpghs0" target="_blank">https://wandb.ai/kushv16/plant-pathology/runs/dfnpghs0</a><br/>
# ...Successfully finished last run (ID:dfnpghs0). Initializing new run:<br/><br/>
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">soft-sunset-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/kushv16/plant-pathology" target="_blank">https://wandb.ai/kushv16/plant-pathology</a><br/>
#                 Run page: <a href="https://wandb.ai/kushv16/plant-pathology/runs/220xcj8w" target="_blank">https://wandb.ai/kushv16/plant-pathology/runs/220xcj8w</a><br/>
#                 Run data is saved locally in <code>/kaggle/working/wandb/run-20210827_124108-220xcj8w</code><br/><br/>

# %%
wandb.config.type = 'baseline'
wandb.config.kaggle_competition = 'Plant Pathology 2021 - FGVC8'

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=optimizer, metrics=[f1])

# %%
history = model.fit(training_set, validation_data= validation_set, callbacks=callbacks_list, epochs = 15) 
run.finish()
# Out:
# Epoch 1/15
# 990/990 [==============================] - 706s 685ms/step - loss: 0.3000 - f1_score: 0.5744 - val_loss: 0.1278 - val_f1_score: 0.8398
#
# Epoch 00001: saving model to training/efficientnet-cp-0001.ckpt
# Epoch 2/15
# 990/990 [==============================] - 656s 663ms/step - loss: 0.1507 - f1_score: 0.8058 - val_loss: 0.1435 - val_f1_score: 0.8226
#
# Epoch 00002: saving model to training/efficientnet-cp-0002.ckpt
# Epoch 3/15
# 990/990 [==============================] - 656s 663ms/step - loss: 0.1274 - f1_score: 0.8306 - val_loss: 0.1372 - val_f1_score: 0.8417
#
# Epoch 00003: saving model to training/efficientnet-cp-0003.ckpt
# Epoch 4/15
# 990/990 [==============================] - 656s 662ms/step - loss: 0.1172 - f1_score: 0.8471 - val_loss: 0.1115 - val_f1_score: 0.8393
#
# Epoch 00004: saving model to training/efficientnet-cp-0004.ckpt
# Epoch 5/15
# 990/990 [==============================] - 656s 662ms/step - loss: 0.1104 - f1_score: 0.8519 - val_loss: 0.1058 - val_f1_score: 0.8637
#
# Epoch 00005: saving model to training/efficientnet-cp-0005.ckpt
# Epoch 6/15
# 990/990 [==============================] - 655s 661ms/step - loss: 0.1027 - f1_score: 0.8622 - val_loss: 0.1116 - val_f1_score: 0.8559
#
# Epoch 00006: saving model to training/efficientnet-cp-0006.ckpt
# Epoch 7/15
# 990/990 [==============================] - 657s 663ms/step - loss: 0.1014 - f1_score: 0.8629 - val_loss: 0.1246 - val_f1_score: 0.8543
#
# Epoch 00007: saving model to training/efficientnet-cp-0007.ckpt
# Epoch 8/15
# 990/990 [==============================] - 658s 664ms/step - loss: 0.0951 - f1_score: 0.8712 - val_loss: 0.0927 - val_f1_score: 0.8875
#
# Epoch 00008: saving model to training/efficientnet-cp-0008.ckpt
# Epoch 9/15
# 990/990 [==============================] - 658s 664ms/step - loss: 0.0925 - f1_score: 0.8719 - val_loss: 0.0975 - val_f1_score: 0.8702
#
# Epoch 00009: saving model to training/efficientnet-cp-0009.ckpt
# Epoch 10/15
# 990/990 [==============================] - 657s 664ms/step - loss: 0.0922 - f1_score: 0.8781 - val_loss: 0.1077 - val_f1_score: 0.8601
#
# Epoch 00010: saving model to training/efficientnet-cp-0010.ckpt
# Epoch 11/15
# 990/990 [==============================] - 656s 663ms/step - loss: 0.0868 - f1_score: 0.8844 - val_loss: 0.0953 - val_f1_score: 0.8851
#
# Epoch 00011: saving model to training/efficientnet-cp-0011.ckpt
# Epoch 12/15
# 990/990 [==============================] - 655s 662ms/step - loss: 0.0843 - f1_score: 0.8851 - val_loss: 0.0920 - val_f1_score: 0.8960
#
# Epoch 00012: saving model to training/efficientnet-cp-0012.ckpt
# Epoch 13/15
# 990/990 [==============================] - 660s 666ms/step - loss: 0.0808 - f1_score: 0.8915 - val_loss: 0.0865 - val_f1_score: 0.8924
#
# Epoch 00013: saving model to training/efficientnet-cp-0013.ckpt
# Epoch 14/15
# 990/990 [==============================] - 658s 664ms/step - loss: 0.0773 - f1_score: 0.8944 - val_loss: 0.0969 - val_f1_score: 0.8860
#
# Epoch 00014: saving model to training/efficientnet-cp-0014.ckpt
# Epoch 15/15
# 990/990 [==============================] - 657s 664ms/step - loss: 0.0757 - f1_score: 0.8950 - val_loss: 0.0905 - val_f1_score: 0.8874
#
# Epoch 00015: saving model to training/efficientnet-cp-0015.ckpt
# <br/>Waiting for W&B process to finish, PID 407<br/>Program ended successfully.
# VBox(children=(Label(value=' 736.86MB of 736.86MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=…
# Find user logs for this run at: <code>/kaggle/working/wandb/run-20210827_124108-220xcj8w/logs/debug.log</code>
# Find internal logs for this run at: <code>/kaggle/working/wandb/run-20210827_124108-220xcj8w/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.07898</td></tr><tr><td>f1_score</td><td>0.89345</td></tr><tr><td>val_loss</td><td>0.09047</td></tr><tr><td>val_f1_score</td><td>0.88741</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>_runtime</td><td>9971</td></tr><tr><td>_timestamp</td><td>1630078044</td></tr><tr><td>_step</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.08655</td></tr><tr><td>best_epoch</td><td>12</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>f1_score</td><td>▁▅▆▆▇▇▇▇▇▇█████</td></tr><tr><td>val_loss</td><td>▆█▇▄▃▄▆▂▂▄▂▂▁▂▁</td></tr><tr><td>val_f1_score</td><td>▃▁▃▃▅▄▄▇▆▅▇██▇▇</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▂▂▂▃▄▄▄▅▆▆▆▇██</td></tr><tr><td>_timestamp</td><td>▁▂▂▂▃▄▄▄▅▆▆▆▇██</td></tr><tr><td>_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">soft-sunset-3</strong>: <a href="https://wandb.ai/kushv16/plant-pathology/runs/220xcj8w" target="_blank">https://wandb.ai/kushv16/plant-pathology/runs/220xcj8w</a><br/>

# %%
model.save('pp_research02(EfficientNet).h5')
